# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("BlackFriday.csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
del df["Product_Category_2"]
del df["Product_Category_3"]

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
df["User_ID"].nunique()
# Out:
# 5891

# %%
df["Product_ID"].nunique()
# Out:
# 3623

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df["Occupation"].nunique()
# Out:
# 21

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["Marital_Status"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["Product_Category_1"].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df["Purchase"].sum() #total amount of money spent on black friday sale
# Out:
# 5017668378

# %%
for column in df.columns:
    print(column,":", df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %%
data=pd.DataFrame( {"Ratio" : [len(df[df["Gender"]=="M"]),len(df[df["Gender"]=="F"])]},index =  ["Male","Female"])

# %%
data.plot.pie(y = "Ratio", figsize =(6,6),autopct="%.2f",title = 'Gender Ratio')
# Out:
# <Axes: title={'center': 'Gender Ratio'}, ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind = 'pie',figsize =(6,6),autopct="%.2f",title = 'Gender Ratio')
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').sum()["Purchase"].plot(kind = 'pie',figsize =(6,6),autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Gender').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.groupby("Age").size().plot(kind='bar',title="Purchase Distribution by age")
# Out:
# <Axes: title={'center': 'Purchase Distribution by age'}, xlabel='Age'>

# %%
df.groupby("Marital_Status").size().plot(kind='pie',title="Purchase Distribution based on maritial status",autopct="%0.2f")
# Out:
# <Axes: title={'center': 'Purchase Distribution based on maritial status'}>

# %%
df.groupby("Gender").size().plot(kind='pie',title="Purchase Distribution by Gender",autopct="%0.2f")
# Out:
# <Axes: title={'center': 'Purchase Distribution by Gender'}>

# %%
sns.set(rc = {'figure.figsize': (12,6)})

sns.countplot(x=  "Age",hue = "Gender",data = df )
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize': (12,6)})

sns.countplot(x=  "Gender",hue = "Age",data = df )
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize': (12,6)})

sns.countplot(x=  "Gender",hue = "Marital_Status",data = df )
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x=  df["City_Category"] )
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind='pie',autopct="%0.2f")
# Out:
# <Axes: >

# %%
sns.countplot(x='City_Category',hue= "Age",data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='Marital_Status',hue= "City_Category",data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.groupby("City_Category").sum()['Purchase'].plot(kind="pie",autopct="%0.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(x=df["Stay_In_Current_City_Years"])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = "Stay_In_Current_City_Years",hue = 'Gender',data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = "Stay_In_Current_City_Years",hue = 'Marital_Status',data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = "Stay_In_Current_City_Years",hue = 'City_Category',data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = "Stay_In_Current_City_Years",hue = 'Age',data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years").sum()['Purchase'].plot(kind="pie",autopct="%0.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x='Marital_Status',hue='Gender',data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x='Occupation',hue='Gender',data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
sns.countplot(x='Product_Category_1',hue="Gender",data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
l=[]
for i in range(len(df)):
    l.append(df['Gender'][i]+'_'+str(df['Marital_Status'][i]))
        
df['MaritalGender']=l

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
sns.countplot(x='MaritalGender',data=df)
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %%
df.groupby('MaritalGender').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='MaritalGender'>

# %%
df.groupby('MaritalGender').mean()['Purchase'].sort_values().plot(kind = 'bar')
